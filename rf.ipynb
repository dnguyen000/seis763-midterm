# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score,
    confusion_matrix, ConfusionMatrixDisplay,  classification_report
)

# %%
spy  = pd.read_csv('data/SPY_features.csv',  parse_dates=['date'], index_col='date').sort_index()

# %%
spy.head()
# Out:
#              adj_close       close        high         low        open  \
# date
# 2015-01-02  170.125015  205.429993  206.880005  204.179993  206.380005
# 2015-01-05  167.052658  201.720001  204.369995  201.350006  204.169998
# 2015-01-06  165.479141  199.820007  202.720001  198.860001  202.089996
# 2015-01-07  167.541260  202.309998  202.720001  200.880005  201.419998
# 2015-01-08  170.514206  205.899994  206.160004  203.990005  204.009995
#
#                volume  daily_return  weekly_return        ma_7       ma_21  \
# date
# 2015-01-02  121465900     -0.000535      -0.011262  171.691376  169.676133
# 2015-01-05  169632600     -0.018059      -0.032239  170.977999  169.477819
# 2015-01-06  209151400     -0.009419      -0.042641  170.037469  169.213594
# 2015-01-07  125346700      0.012462      -0.025481  169.312267  169.034233
# 2015-01-08  147217800      0.017745       0.001751  168.978638  169.050955
#
#             ...  lag_return_5  month  quarter  season_num  season  \
# date        ...
# 2015-01-02  ...      0.000096      1        1           0  Winter
# 2015-01-05  ...      0.003225      1        1           0  Winter
# 2015-01-06  ...      0.001344      1        1           0  Winter
# 2015-01-07  ...     -0.005366      1        1           0  Winter
# 2015-01-08  ...     -0.009923      1        1           0  Winter
#
#             is_earnings_week        vix  is_major_event  target_direction  \
# date
# 2015-01-02                 0  17.790001               0                 0
# 2015-01-05                 0  19.920000               0                 0
# 2015-01-06                 0  21.120001               0                 1
# 2015-01-07                 0  19.309999               0                 1
# 2015-01-08                 0  17.010000               0                 0
#
#             target_return
# date
# 2015-01-02      -0.005744
# 2015-01-05       0.004610
# 2015-01-06       0.011310
# 2015-01-07      -0.007167
# 2015-01-08      -0.033414
#
# [5 rows x 35 columns]

# %%
FEATURES = [
    'daily_return', 'weekly_return', 'ma_cross', 'dist_from_ma21', 'daily_range',
    'rsi_14', 'macd_hist', 'bb_position', 'volatility_7', 'volatility_20',
    'volume_change', 'volume_ratio',
    'lag_return_1', 'lag_return_3', 'lag_return_5',
    'month', 'is_earnings_week',
    'vix', 'is_major_event'
]
TARGET_CLS = 'target_direction'

# %%
spy_cls  = spy[FEATURES + [TARGET_CLS]].dropna().copy()

print(spy_cls.shape)
# Out:
# (2515, 20)

# %%
def walk_forward_splits(df, train_window, test_window=42, embargo=5):
    """
    Generates (train_idx, test_idx) pairs for walk-forward validation.
    embargo = gap between train end and test start to prevent leakage
    from lagged features (lag_return_5, weekly_return, volatility_20 etc.)
    
    Fold 1: Train [0 → 62]  Gap [63 → 67]  Test [68 → 109]
    Fold 2: Train [42 → 104] Gap [105 → 109] Test [110 → 151]
    """
    splits = []
    n = len(df)
    start = 0

    while start + train_window + embargo + test_window <= n:
        train_start = start
        train_end   = start + train_window

        test_start  = train_end + embargo
        test_end    = test_start + test_window

        train_idx = list(range(train_start, train_end))
        test_idx  = list(range(test_start, test_end))

        splits.append((train_idx, test_idx))

        
        start += test_window

    return splits

# %%
spy_folds = walk_forward_splits(spy_cls, train_window = 189)
print("SPY folds:", len(spy_folds))
# Out:
# SPY folds: 55

# %%
fold_scores = []
spy_actual, spy_pred = [], []
spy_probs = []

# %%
all_importances = []

# %%
for i, (train_idx, test_idx) in enumerate(spy_folds):
    X_train = spy_cls.iloc[train_idx][FEATURES]
    y_train = spy_cls.iloc[train_idx][TARGET_CLS]
    X_test  = spy_cls.iloc[test_idx][FEATURES]
    y_test  = spy_cls.iloc[test_idx][TARGET_CLS]

    rf = RandomForestClassifier(n_estimators=100, random_state=42, class_weight='balanced')
    rf.fit(X_train, y_train)

   
    y_p = rf.predict(X_test)
    y_prob = rf.predict_proba(X_test)[:, 1]

   
    cm = confusion_matrix(y_test, y_p, labels=[0, 1])
    tn, fp, fn, tp = cm.ravel()
    spec = tn / (tn + fp) if (tn + fp) > 0 else 0

    fold_scores.append({
        'accuracy': accuracy_score(y_test, y_p),
        'f1': f1_score(y_test, y_p, zero_division=0),
        'precision': precision_score(y_test, y_p, zero_division=0),
        'recall': recall_score(y_test, y_p, zero_division=0),
        'specificity': spec
    })

    spy_actual.extend(y_test)
    spy_pred.extend(y_p)
    spy_probs.extend(y_prob)
    all_importances.append(rf.feature_importances_)

# %%
results_df = pd.DataFrame(fold_scores)
results_df
# Out:
#     accuracy        f1  precision    recall  specificity
# 0   0.595238  0.451613   0.500000  0.411765     0.720000
# 1   0.595238  0.690909   0.558824  0.904762     0.285714
# 2   0.476190  0.476190   0.588235  0.400000     0.588235
# 3   0.571429  0.470588   0.800000  0.333333     0.888889
# 4   0.357143  0.372093   0.400000  0.347826     0.368421
# 5   0.523810  0.615385   0.516129  0.761905     0.285714
# 6   0.666667  0.730769   0.678571  0.791667     0.500000
# 7   0.547619  0.486486   0.600000  0.409091     0.700000
# 8   0.547619  0.486486   0.600000  0.409091     0.700000
# 9   0.523810  0.333333   0.555556  0.238095     0.809524
# 10  0.380952  0.315789   0.400000  0.260870     0.526316
# 11  0.523810  0.677419   0.636364  0.724138     0.076923
# 12  0.595238  0.679245   0.666667  0.692308     0.437500
# 13  0.333333  0.333333   0.388889  0.291667     0.388889
# 14  0.571429  0.700000   0.567568  0.913043     0.157895
# 15  0.452381  0.410256   0.533333  0.333333     0.611111
# 16  0.547619  0.558140   0.600000  0.521739     0.578947
# 17  0.571429  0.689655   0.555556  0.909091     0.200000
# 18  0.500000  0.618182   0.485714  0.850000     0.181818
# 19  0.333333  0.363636   0.444444  0.307692     0.375000
# 20  0.642857  0.716981   0.678571  0.760000     0.470588
# 21  0.547619  0.536585   0.550000  0.523810     0.571429
# 22  0.523810  0.545455   0.571429  0.521739     0.526316
# 23  0.333333  0.461538   0.400000  0.545455     0.100000
# 24  0.523810  0.629630   0.607143  0.653846     0.312500
# 25  0.476190  0.607143   0.653846  0.566667     0.250000
# 26  0.404762  0.545455   0.405405  0.833333     0.083333
# 27  0.523810  0.523810   0.647059  0.440000     0.647059
# 28  0.738095  0.830769   0.750000  0.931034     0.307692
# 29  0.642857  0.761905   0.666667  0.888889     0.200000
# 30  0.500000  0.588235   0.483871  0.750000     0.272727
# 31  0.595238  0.738462   0.615385  0.923077     0.062500
# 32  0.595238  0.721311   0.578947  0.956522     0.157895
# 33  0.428571  0.555556   0.483871  0.652174     0.157895
# 34  0.500000  0.553191   0.590909  0.520000     0.470588
# 35  0.619048  0.703704   0.575758  0.904762     0.333333
# 36  0.476190  0.560000   0.700000  0.466667     0.500000
# 37  0.500000  0.618182   0.459459  0.944444     0.166667
# 38  0.333333  0.500000   0.368421  0.777778     0.000000
# 39  0.380952  0.480000   0.400000  0.600000     0.181818
# 40  0.428571  0.500000   0.428571  0.600000     0.272727
# 41  0.404762  0.324324   0.272727  0.400000     0.407407
# 42  0.595238  0.370370   0.625000  0.263158     0.869565
# 43  0.452381  0.148148   0.400000  0.090909     0.850000
# 44  0.452381  0.439024   0.473684  0.409091     0.500000
# 45  0.547619  0.344828   1.000000  0.208333     1.000000
# 46  0.523810  0.333333   0.625000  0.227273     0.850000
# 47  0.619048  0.692308   0.580645  0.857143     0.380952
# 48  0.428571  0.454545   0.555556  0.384615     0.500000
# 49  0.380952  0.380952   0.500000  0.307692     0.500000
# 50  0.357143  0.490566   0.393939  0.650000     0.090909
# 51  0.619048  0.741935   0.676471  0.821429     0.214286
# 52  0.523810  0.629630   0.607143  0.653846     0.312500
# 53  0.523810  0.677419   0.567568  0.840000     0.058824
# 54  0.476190  0.633333   0.558824  0.730769     0.062500

# %%
prob_df = pd.DataFrame({
    'actual': spy_actual,
    'prob_up': spy_probs

})

high_conviction_up = prob_df[prob_df['prob_up'] > 0.55]
high_conviction_down = prob_df[prob_df['prob_up'] < 0.45]

acc_up = (high_conviction_up['actual'] == 1).mean()
acc_down = (high_conviction_down['actual'] == 0).mean()

print(f"Accuracy when Prob > 0.55 (UP): {acc_up:.4f} (Samples: {len(high_conviction_up)})")
print(f"Accuracy when Prob < 0.45 (DOWN): {acc_down:.4f} (Samples: {len(high_conviction_down)})")
# Out:
# Accuracy when Prob > 0.55 (UP): 0.5525 (Samples: 1086)
# Accuracy when Prob < 0.45 (DOWN): 0.4463 (Samples: 596)

# %%
results_df.describe()
# Out:
#         accuracy         f1  precision     recall  specificity
# count  55.000000  55.000000  55.000000  55.000000    55.000000
# mean    0.506061   0.541784   0.555049   0.589379     0.400417
# std     0.095152   0.145639   0.123174   0.240619     0.251521
# min     0.333333   0.148148   0.272727   0.090909     0.000000
# 25%     0.440476   0.453079   0.478778   0.400000     0.190909
# 50%     0.523810   0.545455   0.567568   0.600000     0.375000
# 75%     0.571429   0.677419   0.620192   0.806548     0.548872
# max     0.738095   0.830769   1.000000   0.956522     1.000000

# %%
avg_importance = np.mean(all_importances, axis=0)
feat_imp = pd.Series(avg_importance, index=FEATURES).sort_values(ascending=False)
feat_imp
# Out:
# lag_return_5        0.067448
# volume_change       0.066925
# daily_return        0.066555
# lag_return_3        0.066421
# volume_ratio        0.063001
# ma_cross            0.062750
# lag_return_1        0.062473
# daily_range         0.060774
# vix                 0.057362
# macd_hist           0.057336
# rsi_14              0.057197
# weekly_return       0.056874
# volatility_20       0.056410
# volatility_7        0.055860
# bb_position         0.054153
# dist_from_ma21      0.052180
# month               0.029811
# is_earnings_week    0.005410
# is_major_event      0.001060
# dtype: float64

# %%
print(classification_report(spy_actual, spy_pred, zero_division=0))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.45      0.40      0.42      1038
#            1       0.55      0.59      0.57      1272
#
#     accuracy                           0.51      2310
#    macro avg       0.50      0.50      0.50      2310
# weighted avg       0.50      0.51      0.50      2310

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x=feat_imp.values, y=feat_imp.index)
plt.title("SPY: Average Feature Importance (Default RF)")
plt.xlabel("Importance Score")
plt.show()

# %%
n_estimators_values  = [100, 200, 500]
max_depth_values     = [4, 6, 8, 10, None]
min_samples_leaf_values = [1, 5, 10, 20]
max_features_values  = ['sqrt', 'log2']

from itertools import product
combos = list(product(n_estimators_values, max_depth_values, min_samples_leaf_values, max_features_values))
print(f'Grid: {len(n_estimators_values)} n_estimators x {len(max_depth_values)} max_depth x {len(min_samples_leaf_values)} min_samples_leaf x {len(max_features_values)} max_features = {len(combos)} combinations')
print(f'Folds per combo: {len(spy_folds)}')
print(f'Total RF fits: {len(combos) * len(spy_folds)}')
# Out:
# Grid: 3 n_estimators x 5 max_depth x 4 min_samples_leaf x 2 max_features = 120 combinations
# Folds per combo: 55
# Total RF fits: 6600

# %%
grid_results = []

for n_est, max_d, min_leaf, max_feat in combos:
    fold_f1s   = []
    fold_accs  = []
    fold_precs = []
    fold_recs  = []
    fold_specs = []

    for train_idx, test_idx in spy_folds:
        X_train = spy_cls.iloc[train_idx][FEATURES]
        y_train = spy_cls.iloc[train_idx][TARGET_CLS]
        X_test  = spy_cls.iloc[test_idx][FEATURES]
        y_test  = spy_cls.iloc[test_idx][TARGET_CLS]

        rf = RandomForestClassifier(
            n_estimators=n_est,
            max_depth=max_d,
            min_samples_leaf=min_leaf,
            max_features=max_feat,
            class_weight='balanced',
            random_state=42,
            n_jobs=-1
        )
        rf.fit(X_train, y_train)
        y_pred = rf.predict(X_test)

        fold_f1s.append(f1_score(y_test, y_pred, zero_division=0))
        fold_accs.append(accuracy_score(y_test, y_pred))
        fold_precs.append(precision_score(y_test, y_pred, zero_division=0))
        fold_recs.append(recall_score(y_test, y_pred, zero_division=0))

        cm = confusion_matrix(y_test, y_pred, labels=[0, 1])
        tn, fp, fn, tp = cm.ravel()
        spec = tn / (tn + fp) if (tn + fp) > 0 else 0.0
        fold_specs.append(spec)

    grid_results.append({
        'n_estimators':    n_est,
        'max_depth':       max_d,
        'min_samples_leaf': min_leaf,
        'max_features':    max_feat,
        'f1':          np.mean(fold_f1s),
        'accuracy':    np.mean(fold_accs),
        'precision':   np.mean(fold_precs),
        'recall':      np.mean(fold_recs),
        'specificity': np.mean(fold_specs),
    })
    print(f'  n_est={n_est:>3}  depth={str(max_d):<5}  min_leaf={min_leaf:<3}  max_feat={max_feat:<5}  '
          f'F1={np.mean(fold_f1s):.3f}  acc={np.mean(fold_accs):.3f}  '
          f'prec={np.mean(fold_precs):.3f}  rec={np.mean(fold_recs):.3f}  spec={np.mean(fold_specs):.3f}')

rf_grid_df = pd.DataFrame(grid_results)
# Out:
#   n_est=100  depth=4      min_leaf=1    max_feat=sqrt   F1=0.531  acc=0.504  prec=0.550  rec=0.563  spec=0.437
#   n_est=100  depth=4      min_leaf=1    max_feat=log2   F1=0.531  acc=0.504  prec=0.550  rec=0.563  spec=0.437
#   n_est=100  depth=4      min_leaf=5    max_feat=sqrt   F1=0.531  acc=0.508  prec=0.556  rec=0.558  spec=0.452
#   n_est=100  depth=4      min_leaf=5    max_feat=log2   F1=0.531  acc=0.508  prec=0.556  rec=0.558  spec=0.452
#   n_est=100  depth=4      min_leaf=10   max_feat=sqrt   F1=0.533  acc=0.513  prec=0.561  rec=0.554  spec=0.467
#   n_est=100  depth=4      min_leaf=10   max_feat=log2   F1=0.533  acc=0.513  prec=0.561  rec=0.554  spec=0.467
#   n_est=100  depth=4      min_leaf=20   max_feat=sqrt   F1=0.517  acc=0.507  prec=0.567  rec=0.528  spec=0.490
#   n_est=100  depth=4      min_leaf=20   max_feat=log2   F1=0.517  acc=0.507  prec=0.567  rec=0.528  spec=0.490
#   n_est=100  depth=6      min_leaf=1    max_feat=sqrt   F1=0.544  acc=0.510  prec=0.558  rec=0.580  spec=0.427
#   n_est=100  depth=6      min_leaf=1    max_feat=log2   F1=0.544  acc=0.510  prec=0.558  rec=0.580  spec=0.427
#   n_est=100  depth=6      min_leaf=5    max_feat=sqrt   F1=0.555  acc=0.530  prec=0.584  rec=0.581  spec=0.473
#   n_est=100  depth=6      min_leaf=5    max_feat=log2   F1=0.555  acc=0.530  prec=0.584  rec=0.581  spec=0.473
#   n_est=100  depth=6      min_leaf=10   max_feat=sqrt   F1=0.538  acc=0.517  prec=0.564  rec=0.559  spec=0.471
#   n_est=100  depth=6      min_leaf=10   max_feat=log2   F1=0.538  acc=0.517  prec=0.564  rec=0.559  spec=0.471
#   n_est=100  depth=6      min_leaf=20   max_feat=sqrt   F1=0.517  acc=0.507  prec=0.567  rec=0.528  spec=0.490
#   n_est=100  depth=6      min_leaf=20   max_feat=log2   F1=0.517  acc=0.507  prec=0.567  rec=0.528  spec=0.490
#   n_est=100  depth=8      min_leaf=1    max_feat=sqrt   F1=0.549  acc=0.506  prec=0.551  rec=0.601  spec=0.387
#   n_est=100  depth=8      min_leaf=1    max_feat=log2   F1=0.549  acc=0.506  prec=0.551  rec=0.601  spec=0.387
#   n_est=100  depth=8      min_leaf=5    max_feat=sqrt   F1=0.544  acc=0.518  prec=0.570  rec=0.571  spec=0.460
#   n_est=100  depth=8      min_leaf=5    max_feat=log2   F1=0.544  acc=0.518  prec=0.570  rec=0.571  spec=0.460
#   n_est=100  depth=8      min_leaf=10   max_feat=sqrt   F1=0.537  acc=0.515  prec=0.567  rec=0.556  spec=0.470
#   n_est=100  depth=8      min_leaf=10   max_feat=log2   F1=0.537  acc=0.515  prec=0.567  rec=0.556  spec=0.470
#   n_est=100  depth=8      min_leaf=20   max_feat=sqrt   F1=0.517  acc=0.507  prec=0.567  rec=0.528  spec=0.490
#   n_est=100  depth=8      min_leaf=20   max_feat=log2   F1=0.517  acc=0.507  prec=0.567  rec=0.528  spec=0.490
#   n_est=100  depth=10     min_leaf=1    max_feat=sqrt   F1=0.547  acc=0.507  prec=0.552  rec=0.595  spec=0.393
#   n_est=100  depth=10     min_leaf=1    max_feat=log2   F1=0.547  acc=0.507  prec=0.552  rec=0.595  spec=0.393
#   n_est=100  depth=10     min_leaf=5    max_feat=sqrt   F1=0.539  acc=0.515  prec=0.565  rec=0.565  spec=0.459
#   n_est=100  depth=10     min_leaf=5    max_feat=log2   F1=0.539  acc=0.515  prec=0.565  rec=0.565  spec=0.459
#   n_est=100  depth=10     min_leaf=10   max_feat=sqrt   F1=0.536  acc=0.515  prec=0.567  rec=0.555  spec=0.470
#   n_est=100  depth=10     min_leaf=10   max_feat=log2   F1=0.536  acc=0.515  prec=0.567  rec=0.555  spec=0.470
#   n_est=100  depth=10     min_leaf=20   max_feat=sqrt   F1=0.517  acc=0.507  prec=0.567  rec=0.528  spec=0.490
#   n_est=100  depth=10     min_leaf=20   max_feat=log2   F1=0.517  acc=0.507  prec=0.567  rec=0.528  spec=0.490
#   n_est=100  depth=None   min_leaf=1    max_feat=sqrt   F1=0.542  acc=0.506  prec=0.555  rec=0.589  spec=0.400
#   n_est=100  depth=None   min_leaf=1    max_feat=log2   F1=0.542  acc=0.506  prec=0.555  rec=0.589  spec=0.400
#   n_est=100  depth=None   min_leaf=5    max_feat=sqrt   F1=0.542  acc=0.518  prec=0.569  rec=0.567  spec=0.464
#   n_est=100  depth=None   min_leaf=5    max_feat=log2   F1=0.542  acc=0.518  prec=0.569  rec=0.567  spec=0.464
#   n_est=100  depth=None   min_leaf=10   max_feat=sqrt   F1=0.536  acc=0.515  prec=0.567  rec=0.555  spec=0.470
#   n_est=100  depth=None   min_leaf=10   max_feat=log2   F1=0.536  acc=0.515  prec=0.567  rec=0.555  spec=0.470
#   n_est=100  depth=None   min_leaf=20   max_feat=sqrt   F1=0.517  acc=0.507  prec=0.567  rec=0.528  spec=0.490
#   n_est=100  depth=None   min_leaf=20   max_feat=log2   F1=0.517  acc=0.507  prec=0.567  rec=0.528  spec=0.490
#   n_est=200  depth=4      min_leaf=1    max_feat=sqrt   F1=0.534  acc=0.506  prec=0.566  rec=0.565  spec=0.444
#   n_est=200  depth=4      min_leaf=1    max_feat=log2   F1=0.534  acc=0.506  prec=0.566  rec=0.565  spec=0.444
#   n_est=200  depth=4      min_leaf=5    max_feat=sqrt   F1=0.530  acc=0.507  prec=0.554  rec=0.558  spec=0.453
#   n_est=200  depth=4      min_leaf=5    max_feat=log2   F1=0.530  acc=0.507  prec=0.554  rec=0.558  spec=0.453
#   n_est=200  depth=4      min_leaf=10   max_feat=sqrt   F1=0.536  acc=0.516  prec=0.565  rec=0.559  spec=0.473
#   n_est=200  depth=4      min_leaf=10   max_feat=log2   F1=0.536  acc=0.516  prec=0.565  rec=0.559  spec=0.473
#   n_est=200  depth=4      min_leaf=20   max_feat=sqrt   F1=0.517  acc=0.506  prec=0.565  rec=0.532  spec=0.481
#   n_est=200  depth=4      min_leaf=20   max_feat=log2   F1=0.517  acc=0.506  prec=0.565  rec=0.532  spec=0.481
#   n_est=200  depth=6      min_leaf=1    max_feat=sqrt   F1=0.544  acc=0.510  prec=0.554  rec=0.584  spec=0.421
#   n_est=200  depth=6      min_leaf=1    max_feat=log2   F1=0.544  acc=0.510  prec=0.554  rec=0.584  spec=0.421
#   n_est=200  depth=6      min_leaf=5    max_feat=sqrt   F1=0.537  acc=0.513  prec=0.567  rec=0.561  spec=0.459
#   n_est=200  depth=6      min_leaf=5    max_feat=log2   F1=0.537  acc=0.513  prec=0.567  rec=0.561  spec=0.459
#   n_est=200  depth=6      min_leaf=10   max_feat=sqrt   F1=0.535  acc=0.515  prec=0.561  rec=0.558  spec=0.469
#   n_est=200  depth=6      min_leaf=10   max_feat=log2   F1=0.535  acc=0.515  prec=0.561  rec=0.558  spec=0.469
#   n_est=200  depth=6      min_leaf=20   max_feat=sqrt   F1=0.516  acc=0.506  prec=0.565  rec=0.531  spec=0.482
#   n_est=200  depth=6      min_leaf=20   max_feat=log2   F1=0.516  acc=0.506  prec=0.565  rec=0.531  spec=0.482
#   n_est=200  depth=8      min_leaf=1    max_feat=sqrt   F1=0.559  acc=0.511  prec=0.558  rec=0.613  spec=0.386
#   n_est=200  depth=8      min_leaf=1    max_feat=log2   F1=0.559  acc=0.511  prec=0.558  rec=0.613  spec=0.386
#   n_est=200  depth=8      min_leaf=5    max_feat=sqrt   F1=0.543  acc=0.518  prec=0.569  rec=0.569  spec=0.459
#   n_est=200  depth=8      min_leaf=5    max_feat=log2   F1=0.543  acc=0.518  prec=0.569  rec=0.569  spec=0.459
#   n_est=200  depth=8      min_leaf=10   max_feat=sqrt   F1=0.539  acc=0.517  prec=0.571  rec=0.561  spec=0.469
#   n_est=200  depth=8      min_leaf=10   max_feat=log2   F1=0.539  acc=0.517  prec=0.571  rec=0.561  spec=0.469
#   n_est=200  depth=8      min_leaf=20   max_feat=sqrt   F1=0.516  acc=0.506  prec=0.565  rec=0.531  spec=0.482
#   n_est=200  depth=8      min_leaf=20   max_feat=log2   F1=0.516  acc=0.506  prec=0.565  rec=0.531  spec=0.482
#   n_est=200  depth=10     min_leaf=1    max_feat=sqrt   F1=0.564  acc=0.518  prec=0.566  rec=0.616  spec=0.395
#   n_est=200  depth=10     min_leaf=1    max_feat=log2   F1=0.564  acc=0.518  prec=0.566  rec=0.616  spec=0.395
#   n_est=200  depth=10     min_leaf=5    max_feat=sqrt   F1=0.543  acc=0.517  prec=0.568  rec=0.569  spec=0.459
#   n_est=200  depth=10     min_leaf=5    max_feat=log2   F1=0.543  acc=0.517  prec=0.568  rec=0.569  spec=0.459
#   n_est=200  depth=10     min_leaf=10   max_feat=sqrt   F1=0.539  acc=0.517  prec=0.571  rec=0.561  spec=0.469
#   n_est=200  depth=10     min_leaf=10   max_feat=log2   F1=0.539  acc=0.517  prec=0.571  rec=0.561  spec=0.469
#   n_est=200  depth=10     min_leaf=20   max_feat=sqrt   F1=0.516  acc=0.506  prec=0.565  rec=0.531  spec=0.482
#   n_est=200  depth=10     min_leaf=20   max_feat=log2   F1=0.516  acc=0.506  prec=0.565  rec=0.531  spec=0.482
#   n_est=200  depth=None   min_leaf=1    max_feat=sqrt   F1=0.557  acc=0.512  prec=0.557  rec=0.613  spec=0.385
#   n_est=200  depth=None   min_leaf=1    max_feat=log2   F1=0.557  acc=0.512  prec=0.557  rec=0.613  spec=0.385
#   n_est=200  depth=None   min_leaf=5    max_feat=sqrt   F1=0.546  acc=0.520  prec=0.570  rec=0.573  spec=0.459
#   n_est=200  depth=None   min_leaf=5    max_feat=log2   F1=0.546  acc=0.520  prec=0.570  rec=0.573  spec=0.459
#   n_est=200  depth=None   min_leaf=10   max_feat=sqrt   F1=0.539  acc=0.517  prec=0.571  rec=0.561  spec=0.469
#   n_est=200  depth=None   min_leaf=10   max_feat=log2   F1=0.539  acc=0.517  prec=0.571  rec=0.561  spec=0.469
#   n_est=200  depth=None   min_leaf=20   max_feat=sqrt   F1=0.516  acc=0.506  prec=0.565  rec=0.531  spec=0.482
#   n_est=200  depth=None   min_leaf=20   max_feat=log2   F1=0.516  acc=0.506  prec=0.565  rec=0.531  spec=0.482
#   n_est=500  depth=4      min_leaf=1    max_feat=sqrt   F1=0.528  acc=0.504  prec=0.559  rec=0.556  spec=0.445
#   n_est=500  depth=4      min_leaf=1    max_feat=log2   F1=0.528  acc=0.504  prec=0.559  rec=0.556  spec=0.445
#   n_est=500  depth=4      min_leaf=5    max_feat=sqrt   F1=0.527  acc=0.507  prec=0.551  rec=0.554  spec=0.454
#   n_est=500  depth=4      min_leaf=5    max_feat=log2   F1=0.527  acc=0.507  prec=0.551  rec=0.554  spec=0.454
#   n_est=500  depth=4      min_leaf=10   max_feat=sqrt   F1=0.533  acc=0.516  prec=0.584  rec=0.552  spec=0.478
#   n_est=500  depth=4      min_leaf=10   max_feat=log2   F1=0.533  acc=0.516  prec=0.584  rec=0.552  spec=0.478
#   n_est=500  depth=4      min_leaf=20   max_feat=sqrt   F1=0.506  acc=0.504  prec=0.560  rec=0.518  spec=0.496
#   n_est=500  depth=4      min_leaf=20   max_feat=log2   F1=0.506  acc=0.504  prec=0.560  rec=0.518  spec=0.496
#   n_est=500  depth=6      min_leaf=1    max_feat=sqrt   F1=0.547  acc=0.513  prec=0.556  rec=0.590  spec=0.419
#   n_est=500  depth=6      min_leaf=1    max_feat=log2   F1=0.547  acc=0.513  prec=0.556  rec=0.590  spec=0.419
#   n_est=500  depth=6      min_leaf=5    max_feat=sqrt   F1=0.539  acc=0.514  prec=0.574  rec=0.568  spec=0.450
#   n_est=500  depth=6      min_leaf=5    max_feat=log2   F1=0.539  acc=0.514  prec=0.574  rec=0.568  spec=0.450
#   n_est=500  depth=6      min_leaf=10   max_feat=sqrt   F1=0.535  acc=0.516  prec=0.570  rec=0.558  spec=0.471
#   n_est=500  depth=6      min_leaf=10   max_feat=log2   F1=0.535  acc=0.516  prec=0.570  rec=0.558  spec=0.471
#   n_est=500  depth=6      min_leaf=20   max_feat=sqrt   F1=0.506  acc=0.505  prec=0.560  rec=0.518  spec=0.497
#   n_est=500  depth=6      min_leaf=20   max_feat=log2   F1=0.506  acc=0.505  prec=0.560  rec=0.518  spec=0.497
#   n_est=500  depth=8      min_leaf=1    max_feat=sqrt   F1=0.560  acc=0.520  prec=0.564  rec=0.615  spec=0.404
#   n_est=500  depth=8      min_leaf=1    max_feat=log2   F1=0.560  acc=0.520  prec=0.564  rec=0.615  spec=0.404
#   n_est=500  depth=8      min_leaf=5    max_feat=sqrt   F1=0.540  acc=0.513  prec=0.571  rec=0.570  spec=0.447
#   n_est=500  depth=8      min_leaf=5    max_feat=log2   F1=0.540  acc=0.513  prec=0.571  rec=0.570  spec=0.447
#   n_est=500  depth=8      min_leaf=10   max_feat=sqrt   F1=0.534  acc=0.514  prec=0.568  rec=0.557  spec=0.467
#   n_est=500  depth=8      min_leaf=10   max_feat=log2   F1=0.534  acc=0.514  prec=0.568  rec=0.557  spec=0.467
#   n_est=500  depth=8      min_leaf=20   max_feat=sqrt   F1=0.506  acc=0.505  prec=0.560  rec=0.518  spec=0.497
#   n_est=500  depth=8      min_leaf=20   max_feat=log2   F1=0.506  acc=0.505  prec=0.560  rec=0.518  spec=0.497
#   n_est=500  depth=10     min_leaf=1    max_feat=sqrt   F1=0.563  acc=0.519  prec=0.563  rec=0.619  spec=0.392
#   n_est=500  depth=10     min_leaf=1    max_feat=log2   F1=0.563  acc=0.519  prec=0.563  rec=0.619  spec=0.392
#   n_est=500  depth=10     min_leaf=5    max_feat=sqrt   F1=0.541  acc=0.513  prec=0.569  rec=0.570  spec=0.445
#   n_est=500  depth=10     min_leaf=5    max_feat=log2   F1=0.541  acc=0.513  prec=0.569  rec=0.570  spec=0.445
#   n_est=500  depth=10     min_leaf=10   max_feat=sqrt   F1=0.534  acc=0.514  prec=0.568  rec=0.557  spec=0.467
#   n_est=500  depth=10     min_leaf=10   max_feat=log2   F1=0.534  acc=0.514  prec=0.568  rec=0.557  spec=0.467
#   n_est=500  depth=10     min_leaf=20   max_feat=sqrt   F1=0.506  acc=0.505  prec=0.560  rec=0.518  spec=0.497
#   n_est=500  depth=10     min_leaf=20   max_feat=log2   F1=0.506  acc=0.505  prec=0.560  rec=0.518  spec=0.497
#   n_est=500  depth=None   min_leaf=1    max_feat=sqrt   F1=0.550  acc=0.510  prec=0.548  rec=0.610  spec=0.382
#   n_est=500  depth=None   min_leaf=1    max_feat=log2   F1=0.550  acc=0.510  prec=0.548  rec=0.610  spec=0.382
#   n_est=500  depth=None   min_leaf=5    max_feat=sqrt   F1=0.540  acc=0.511  prec=0.569  rec=0.569  spec=0.445
#   n_est=500  depth=None   min_leaf=5    max_feat=log2   F1=0.540  acc=0.511  prec=0.569  rec=0.569  spec=0.445
#   n_est=500  depth=None   min_leaf=10   max_feat=sqrt   F1=0.534  acc=0.514  prec=0.568  rec=0.557  spec=0.467
#   n_est=500  depth=None   min_leaf=10   max_feat=log2   F1=0.534  acc=0.514  prec=0.568  rec=0.557  spec=0.467
#   n_est=500  depth=None   min_leaf=20   max_feat=sqrt   F1=0.506  acc=0.505  prec=0.560  rec=0.518  spec=0.497
#   n_est=500  depth=None   min_leaf=20   max_feat=log2   F1=0.506  acc=0.505  prec=0.560  rec=0.518  spec=0.497
